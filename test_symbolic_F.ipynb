# %%
import pickle

def load_from_file(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
        F = data['F']
        lmd_time_series = data['lmd_time_series']
        state_time_series = data['state_time_series']
    return F, lmd_time_series, state_time_series

F, lmd_time_series, state_time_series = load_from_file('symbolic_F.pkl')

# %%
print(F[0,0])
# Out:
# r[0]*u[0] + (0.2*lmd0_0 + lmd2_1 + 0.1*q[2]*(2*x2_0 - 2*x_ref[2]))/(m_c + m_p*sin(x1)**2) - (0.2*lmd1_0 + lmd3_1 + 0.1*q[3]*(2*x3_0 - 2*x_ref[3]))*cos(x1)/(l*(m_c + m_p*sin(x1)**2))

# %%
print(lmd_time_series[0,8])
# Out:
# lmd0_9 + 0.1*q[0]*(2*x0 + 3.2*x2 - 2*x_ref[0] + 0.08*(m_p*(g*cos(x1 + 1.2*x3 + 0.04*(-g*(m_c + m_p)*sin(x1 + 0.8*x3 + 0.04*(-g*(m_c + m_p)*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - l*m_p*(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - u0_2*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))))/(l*(m_c + m_p*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2)) + 0.08*(-g*(m_c + m_p)*sin(x1 + 0.2*x3) - l*m_p*(x1 + 0.2*x3)**2*sin(x1 + 0.2*x3)*cos(x1 + 0.2*x3) - u0_1*cos(x1 + 0.2*x3))/(l*(m_c + m_p*sin(x1 + 0.2*x3)**2)) + 0.12*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - l*m_p*(x1 + 0.8*x3 + 0.04*(-g*(m_c + m_p)*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - l*m_p*(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - u0_2*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))))/(l*(m_c + m_p*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2)) + 0.08*(-g*(m_c + m_p)*sin(x1 + 0.2*x3) - l*m_p*(x1 + 0.2*x3)**2*sin(x1 + 0.2*x3)*cos(x1 + 0.2*x3) - u0_1*cos(x1 + 0.2*x3))/(l*(m_c + m_p*sin(x1 + 0.2*x3)**2)) + 0.12*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2*sin(x1 + 0.8*x3 + 0.04*(-g*(m_c + m_p)*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - l*m_p*(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - u0_2*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))))/(l*(m_c + m_p*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2)) + 0.08*(-g*(m_c + m_p)*sin(x1 + 0.2*x3) - l*m_p*(x1 + 0.2*x3)**2*sin(x1 + 0.2*x3)*cos(x1 + 0.2*x3) - u0_1*cos(x1 + 0.2*x3))/(l*(m_c + m_p*sin(x1 + 0.2*x3)**2)) + 0.12*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))*cos(x1 + 0.8*x3 + 0.04*(-g*(m_c + m_p)*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - l*m_p*(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))**2*sin(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2)))*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))) - u0_2*cos(x1 + 0.4*x3 + 0.04*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))))/(l*(m_c + m_p*sin(x1 + 0.4*x3 + 0.04* ...

# %%
print(state_time_series[3,2])
# Out:
# x3 + 0.2*(-g*(m_c + m_p)*sin(x1 + 0.2*x3) - l*m_p*(x1 + 0.2*x3)**2*sin(x1 + 0.2*x3)*cos(x1 + 0.2*x3) - u0_1*cos(x1 + 0.2*x3))/(l*(m_c + m_p*sin(x1 + 0.2*x3)**2)) + 0.2*(-g*(m_c + m_p)*sin(x1) - l*m_p*x1**2*sin(x1)*cos(x1) - u0_0*cos(x1))/(l*(m_c + m_p*sin(x1)**2))
